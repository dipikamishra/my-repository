# %%
import pyshtools as pysh
import matplotlib.pyplot as plt

from cartopy import crs as ccrs
import pygmt
from palettable import scientific as scm
from pyshtools import constants

# %%
pysh.utils.figstyle(rel_width=0.75)
# %config InlineBackend.figure_format = 'retina'

# %%
clm=pysh.SHGravCoeffs.from_file('gggrx_1200a_sha.tab', format = 'shtools', lmax = 660)

# %%
clm.info()
# Out:
# kind = 'real'
# normalization = '4pi'
# csphase = 1
# lmax = 660
# GM (m3 / s2) = 4902.8001224453
# r0 (m) = 1738.0
# Omega (rad / s) = None
# error_kind = None
# header = ['1.7380000000000000e+03', '4.9028001224453001e+03', '6.4536052689015518e-15', '1200', '1200', '1', '0.0000000000000000e+00', '0.0000000000000000e+00']
# header2 = None
# name = None
# epoch = None

# %%
power = clm.spectrum(convention = 'power', unit = 'per_lm')
fig, ax = clm.plot_spectrum(unit = 'per_lm')
# Out:
#   File "<ipython-input-25-836784d737ea>", line 2
#     fig, ax = clm.plot_spectrum(unit = 'per_lm')
#                 ^
# SyntaxError: invalid character in identifier

# %%
grid = clm.expand()
fig, ax = grid.plot()

# %%
clm= clm.to_array()
print(clm)
# Out:
# [[[ 1.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#     0.00000000e+00  0.00000000e+00]
#   [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#     0.00000000e+00  0.00000000e+00]
#   [-9.08843393e-05  1.46641236e-11  3.46730965e-05 ...  0.00000000e+00
#     0.00000000e+00  0.00000000e+00]
#   ...
#   [-3.19999533e-10 -3.23344658e-10  3.45889570e-10 ... -1.96304726e-09
#     0.00000000e+00  0.00000000e+00]
#   [-2.82231502e-10  1.33892551e-10  9.15779435e-10 ...  1.15027938e-09
#    -7.43003959e-11  0.00000000e+00]
#   [-1.81211439e-10  6.90023242e-10  1.65161213e-10 ... -8.73676810e-10
#    -3.28296356e-10  3.36129572e-10]]
#
#  [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#     0.00000000e+00  0.00000000e+00]
#   [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#     0.00000000e+00  0.00000000e+00]
#   [ 0.00000000e+00  1.17327642e-09  9.07918983e-10 ...  0.00000000e+00
#     0.00000000e+00  0.00000000e+00]
#   ...
#   [ 0.00000000e+00  1.11023754e-10  2.29366285e-10 ... -1.69804824e-09
#     0.00000000e+00  0.00000000e+00]
#   [ 0.00000000e+00  3.15639396e-10 -2.01405183e-10 ...  4.19004854e-10
#     1.79244674e-09  0.00000000e+00]
#   [ 0.00000000e+00 -1.09794461e-10 -3.23527327e-10 ... -7.51820588e-10
#    -1.82141973e-09 -1.18640381e-09]]]
